# %%
import pandas as pd
import pyarrow
import matplotlib.pyplot as plt
import numpy as np

# %%
X_train_03_14= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_03_14_data.pq")
X_train_03_15= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_03_15_data.pq")
X_train_03_21= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_03_21_data.pq")
X_train_03_22= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_03_22_data.pq")
X_train_03_28= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_03_28_data.pq")
X_train_03_29= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_03_29_data.pq")
X_train_04_04= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_04_04_data.pq")
X_train_04_05= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_04_05_data.pq")
X_train_04_11= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_04_11_data.pq")
X_train_04_12= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_X\\2023_04_12_data.pq")


Y_train_03_14= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_03_14_target.pq")
Y_train_03_15= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_03_15_target.pq")
Y_train_03_21= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_03_21_target.pq")
Y_train_03_22= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_03_22_target.pq")
Y_train_03_28= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_03_28_target.pq")
Y_train_03_29= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_03_29_target.pq")
Y_train_04_04= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_04_04_target.pq")
Y_train_04_05= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_04_05_target.pq")
Y_train_04_11= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_04_11_target.pq")
Y_train_04_12= pd.read_parquet("C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Train_Y\\2023_04_12_target.pq")

# %%
X_test_03_16=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_X\\2023_03_16_data.pq')
Y_test_03_16=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_Y\\2023_03_16_target.pq')

X_test_03_23=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_X\\2023_03_23_data.pq')
Y_test_03_23=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_Y\\2023_03_23_target.pq')

X_test_03_30=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_X\\2023_03_30_data.pq')
Y_test_03_30=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_Y\\2023_03_30_target.pq')

X_test_04_06=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_X\\2023_04_06_data.pq')
Y_test_04_06=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_Y\\2023_04_06_target.pq')

X_test_04_13=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_X\\2023_04_13_data.pq')
Y_test_04_13=pd.read_parquet('C:\\Users\\valif\\OneDrive\\Desktop\\SollIch-Hackathon_Daten\\SollIch-Hackathon_Daten\\Eval_Y\\2023_04_13_target.pq')

# %%
X_train_03_16=pd.concat([X_train_03_14,X_train_03_15])
Y_train_03_16=pd.concat([Y_train_03_14,Y_train_03_15])

X_train_03_23=pd.concat([X_train_03_21,X_train_03_22])
Y_train_03_23=pd.concat([Y_train_03_21,Y_train_03_22])

X_train_03_30=pd.concat([X_train_03_28,X_train_03_29])
Y_train_03_30=pd.concat([Y_train_03_28,Y_train_03_29])

X_train_04_06=pd.concat([X_train_04_04,X_train_04_05])
Y_train_04_06=pd.concat([Y_train_04_04,Y_train_04_05])

X_train_04_13=pd.concat([X_train_04_11,X_train_04_12])
Y_train_04_13=pd.concat([Y_train_04_11,Y_train_04_12])

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler

# %%
def weighted_absolute_error(y_pred,y_true):
    points=0
    for i in range(len(y_true)):
        error=abs(y_pred[i]-y_true[i])
        
        if 0<=error<=0.05:
            points+=1
        
        elif 0.05<error<=0.1:
            points+=0.5
        
        elif 0.1<error<=0.5:
            points+=0.25
        
        else:
            points+=0
    
    return points



def duration_error(y_pred,y_true, bound=0.1):
    count=0
    ghost=0
    points=0
    for i in range(len(y_true)):
        error = abs(y_pred[i]-y_true[i])
        if error>0.1:
            count+=1
            ghost+=1
        else:
            count=0
        
        if count==0 and ghost==0:
            points+=1
            ghost=0
        
        elif count==0 and ghost==1:
            points+=0.5
            ghost=0
        
        elif count==0 and 2<=ghost<=10:
            points+=0.25
            ghost=0
        
        else:
            points+=0
            ghost=0

    return points

# %%
scaler = MinMaxScaler()

X_train_03_16_norm= scaler.fit_transform(X_train_03_16)
X_test_03_16_norm=scaler.transform(X_test_03_16)

X_train_03_23_norm=scaler.fit_transform(X_train_03_23)
X_test_03_23_norm=scaler.transform(X_test_03_23)

X_train_03_30_norm=scaler.fit_transform(X_train_03_30)
X_test_03_30_norm=scaler.transform(X_test_03_30)

X_train_04_06_norm=scaler.fit_transform(X_train_04_06)
X_test_04_06_norm=scaler.transform(X_test_04_06)

X_train_04_13_norm=scaler.fit_transform(X_train_04_13)
X_test_04_13_norm=scaler.transform(X_test_04_13)

# %%
knn=KNeighborsRegressor()
dtr=DecisionTreeRegressor()

# %%
len_y=Y_test_03_16.shape[0]

# %%
knn.fit(X_train_03_16_norm, Y_train_03_16)
y_pred=knn.predict(X_test_03_16_norm)
print('------knn-----')
print(f'wae:{weighted_absolute_error(y_pred, Y_test_03_16.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_03_16.to_numpy())/len_y}')
plt.plot(y_pred, label='knr prediction')

print('-----dtr------')
dtr.fit(X_train_03_16_norm, Y_train_03_16)
y_pred=dtr.predict(X_test_03_16_norm)

plt.plot(y_pred, label='dtr predcition')

print(f'wae:{weighted_absolute_error(y_pred, Y_test_03_16.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_03_16.to_numpy())/len_y}')

plt.plot(Y_test_03_16.to_numpy(), label='true')
plt.legend(loc=9)
plt.title('Prediction for 16.03.23')
# Out:
# ------knn-----
# wae:0.9510716217599158
# de:0.9628368006315697
# -----dtr------
# wae:0.9142921887106914
# de:0.9023844680633324
# Text(0.5, 1.0, 'Prediction for 16.03.23')

# %%
knn.fit(X_train_03_23_norm, Y_train_03_23)
y_pred=knn.predict(X_test_03_23_norm)
print('------knn-----')
print(f'wae:{weighted_absolute_error(y_pred, Y_test_03_23.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_03_23.to_numpy())/len_y}')

print('-----dtr------')
dtr.fit(X_train_03_23_norm, Y_train_03_23)
y_pred=dtr.predict(X_test_03_23_norm)

print(f'wae:{weighted_absolute_error(y_pred, Y_test_03_23.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_03_23.to_numpy())/len_y}')
# Out:
# ------knn-----
# wae:0.8726407508662154
# de:0.8637300624259879
# -----dtr------
# wae:0.9070042835631058
# de:0.8861858744755193

# %%
knn.fit(X_train_03_30_norm, Y_train_03_30)
y_pred=knn.predict(X_test_03_30_norm)
print('------knn-----')
print(f'wae:{weighted_absolute_error(y_pred, Y_test_03_30.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_03_30.to_numpy())/len_y}')

print('-----dtr------')
dtr.fit(X_train_03_30_norm, Y_train_03_30)
y_pred=dtr.predict(X_test_03_30_norm)

print(f'wae:{weighted_absolute_error(y_pred, Y_test_03_30.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_03_30.to_numpy())/len_y}')
# Out:
# ------knn-----
# wae:0.7855221414891596
# de:0.9409072966769492
# -----dtr------
# wae:0.7908583207847838
# de:0.8350755105919504

# %%
knn.fit(X_train_04_06_norm, Y_train_04_06)
y_pred=knn.predict(X_test_04_06_norm)
print('------knn-----')
print(f'wae:{weighted_absolute_error(y_pred, Y_test_04_06.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_04_06.to_numpy())/len_y}')
plt.plot(y_pred[29000:31000])


print('-----dtr------')
dtr.fit(X_train_04_06_norm, Y_train_04_06)
y_pred=dtr.predict(X_test_04_06_norm)
#plt.plot(y_pred)
print(f'wae:{weighted_absolute_error(y_pred, Y_test_04_06.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_04_06.to_numpy())/len_y}')


#plt.plot(Y_test_04_06.to_numpy())
# Out:
# ------knn-----
# wae:0.6535650063595562
# de:0.725851961228637
# -----dtr------
# wae:0.4627015686905162
# de:0.4199353810616804
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\valif\OneDrive\Desktop\SollIch-Hackathon_Daten\sollich_train_per_day.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/valif/OneDrive/Desktop/SollIch-Hackathon_Daten/sollich_train_per_day.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a> print(f'wae:{weighted_absolute_error(y_pred, Y_test_04_06.to_numpy())/len_y}')
#      <a href='vscode-notebook-cell:/c%3A/Users/valif/OneDrive/Desktop/SollIch-Hackathon_Daten/sollich_train_per_day.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a> print(f'de:{duration_error(y_pred,Y_test_04_06.to_numpy())/len_y}')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/valif/OneDrive/Desktop/SollIch-Hackathon_Daten/sollich_train_per_day.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> p
#
# NameError: name 'p' is not defined

# %%
plt.plot(y_pred)

# %%
knn.fit(X_train_04_13_norm, Y_train_04_13)
y_pred=knn.predict(X_test_04_13_norm)
print('------knn-----')
print(f'wae:{weighted_absolute_error(y_pred, Y_test_04_13.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_04_13.to_numpy())/len_y}')
plt.plot(y_pred, label='knr prediction')

print('-----dtr------')
dtr.fit(X_train_04_13_norm, Y_train_04_13)
y_pred=dtr.predict(X_test_04_13_norm)
plt.plot(y_pred, label= 'dtr prediction')
print(f'wae:{weighted_absolute_error(y_pred, Y_test_04_13.to_numpy())/len_y}')
print(f'de:{duration_error(y_pred,Y_test_04_13.to_numpy())/len_y}')

plt.plot(Y_test_04_13.to_numpy(), label='true')
plt.title('Prediction for 13.04.23')
plt.legend(loc=9)
# Out:
# ------knn-----
# wae:0.5801669566234412
# de:0.6391427025920674
# -----dtr------
# wae:0.529235683688835
# de:0.5341588573266473

# %%
plt.subplot(2, 1, 1)  # 2 rows, 1 column, first plot
knn.fit(X_train_03_16_norm, Y_train_03_16)
y_pred = knn.predict(X_test_03_16_norm)
print('------knn-----')
print(f'wae: {weighted_absolute_error(y_pred, Y_test_03_16.to_numpy())/len_y}')
print(f'de: {duration_error(y_pred, Y_test_03_16.to_numpy())/len_y}')
plt.plot(y_pred, label='knr prediction')

print('-----dtr------')
dtr.fit(X_train_03_16_norm, Y_train_03_16)
y_pred = dtr.predict(X_test_03_16_norm)

plt.plot(y_pred, label='dtr prediction')

print(f'wae: {weighted_absolute_error(y_pred, Y_test_03_16.to_numpy())/len_y}')
print(f'de: {duration_error(y_pred, Y_test_03_16.to_numpy())/len_y}')

plt.plot(Y_test_03_16.to_numpy(), label='true')
plt.legend(loc=9)
plt.title('Prediction for 16.03.23')

# Set up the second subplot for 13.04.23
plt.subplot(2, 1, 2)  # 2 rows, 1 column, second plot
knn.fit(X_train_04_13_norm, Y_train_04_13)
y_pred = knn.predict(X_test_04_13_norm)
print('------knn-----')
print(f'wae: {weighted_absolute_error(y_pred, Y_test_04_13.to_numpy())/len_y}')
print(f'de: {duration_error(y_pred, Y_test_04_13.to_numpy())/len_y}')
plt.plot(y_pred, label='knr prediction')

print('-----dtr------')
dtr.fit(X_train_04_13_norm, Y_train_04_13)
y_pred = dtr.predict(X_test_04_13_norm)
plt.plot(y_pred, label='dtr prediction')
print(f'wae: {weighted_absolute_error(y_pred, Y_test_04_13.to_numpy())/len_y}')
print(f'de: {duration_error(y_pred, Y_test_04_13.to_numpy())/len_y}')

plt.plot(Y_test_04_13.to_numpy(), label='true')
plt.title('Prediction for 13.04.23')
plt.legend(loc=9)

# Adjust layout to prevent clipping of titles
plt.tight_layout()

# Show the combined plot
plt.show()
# Out:
# ------knn-----
# wae: 0.9510716217599158
# de: 0.9628368006315697
# -----dtr------
# wae: 0.913089720910513
# de: 0.9006593470855689
# ------knn-----
# wae: 0.5801669566234412
# de: 0.6391427025920674
# -----dtr------
# wae: 0.5265566292890455
# de: 0.5306355170246049

# %% [markdown]
# we started by considering simpler models first such as knregressor and dtregressor, first by concatenatign 2 days of data to predict the third one and then also using all training data for eachday.Parameter tuning do not bring particular increase in generalization performances.
# all models are very good  with the first day but the tend to get worse and worse (maybe add some images of best and worse predictions+ an piece of tree for the sake of it if there's room for it)
#
# performances seem to be pretty similar in both aggregation settings
